# %%
import numpy as np
import pickle

# %%
with open('G.pkl', 'rb') as f:
    res = pickle.load(f)

# %%
res["labels"]
# Out:
# Index(['D_10', 'D_9', 'D_8', 'D_7', 'D_6', 'D_5', 'D_4', 'D_3', 'D_2', 'D_1',
#        'X_1', 'X_2', 'X_3.1', 'X_3.2', 'X_4.1', 'X_4.2', 'X_4.3', 'X_5', 'X_6',
#        'X_7', 'X_8', 'X_9', 'X_10', 'S_1', 'S_2', 'S_3', 'S_4', 'S_5', 'S_6',
#        'S_7', 'S_8', 'S_9', 'S_10', 'T'],
#       dtype='object', name='EventFrameID_Reference')

# %%
X = np.array([[1,2],[2,2]])

# %%
a,b = X[:]

# %%
np.array([[-1.777, np.array([0.28003313]) ]], dtype=float)
# Out:
# C:\Users\jonas\AppData\Local\Temp\ipykernel_7516\4084724961.py:1: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   np.array([[-1.777, np.array([0.28003313]) ]], dtype=float)
# array([[-1.777     ,  0.28003313]])

# %%
print(np.array([0.28003313]))
# Out:
# [0.28003313]

# %%
X = np.load("X.npy")

# %%
temp = X[[2*i for i in range(4)],:]
temp2 = X[[2*i + 1 for i in range(4)],:]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(temp.T)

# %%
plt.plot(temp2.T)
